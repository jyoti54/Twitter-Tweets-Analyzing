# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = "qdv6Il5mrIA5uWZAoHoMYDscV"
consumer_sec = "FQ8eJglVL9Or1yHSBOehHvcspDgSWhgx1uCzlmT7fdyhqtTOQ0"


access_token = "1221293006600323073-dN1KqRGYiElpXC2QlJOc3LEDqmYhWn"
access_token_sec = "XAPxSqQrV4GBTHe3GcFsMx2ZRVmywE7PYCs5cfUHZBdyX"

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
auth.set_access_token(access_token,access_token_sec)

# %%
api_connect = tweepy.API(auth)

# %%
tweet_data = api_connect.search('independence day',count=500)

# %%
# tweet_data
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001E6CCB156A0>, _json={'created_at': 'Sat Aug 14 19:08:57 +0000 2021', 'id': 1426621883584155652, 'id_str': '1426621883584155652', 'text': 'RT @INCIndia: At the stroke of the midnight hour, when the world sleeps, India will awake to life and freedom.: Pt. Jawaharlal Nehru \n\n#Hap…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'INCIndia', 'name': 'Congress', 'id': 1153045459, 'id_str': '1153045459', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1317434616, 'id_str': '1317434616', 'name': "'Don't Lock Justice' (Arshad Chishti)🇮🇳", 'screen_name': 'ArshadChishti_', 'l
# ...

# %%
for tweet in tweet_data:
    print(tweet.text)
# Out:
# @SubaVj16 @Karthik_VFC2 @actorvijay Hi guys happy Independence Day to you and your family members and your friends… https://t.co/wIvFRIaz1L
# @StylesLimited Happy Independence Day
# Let’s make a strong decision, to value our nation and never forget the sacrifices from those who gave us freedom, a… https://t.co/I2RFSVv9vh
# RT @ownerpetrolpump: @shikha_thakur7 Happy independence day Sister https://t.co/xiC1nhv9t3
# May the glory of Independence Day be with us forever. Here's wishing you a very happy Independence Day!
# Visit our w… https://t.co/etxeB6guWo
# RT @MeeraRaj97: #स्वतं#स्वतंत्रतादिवस
# कभी ठंड में ठिठुर कर देख लेना,
# कभी तपती धूप में जल के देख लेना,
# कैसे होती है हिफाजत मुल्क की,
# कभी सरह…
# RT @1Sanjana_Raj: Happy Independence day India Jai Hind 🇮🇳🇮🇳 #IndependenceDayIndia
# #IndependenceDay #15August
#  #15August2021 #स्वतंत्रता…
# ...

# %%
pos=0
neg=0
neu=0

for tweet in tweet_data:
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    if analysis.sentiment.polarity > 0:
        print("Positive")
        pos=pos+1;
    elif analysis.sentiment.polarity == 0:
        print("Neutral")
        neu=neu+1;
    else:
        print("Neutral")
        neg = neg+1
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.25, subjectivity=0.25)
# Positive
# Sentiment(polarity=0.3892857142857143, subjectivity=0.5714285714285714)
# Positive
# Sentiment(polarity=0.9, subjectivity=0.875)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.5166666666666666)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.75, subjectivity=0.9)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.5)
# Positive
# Sentiment(polarity=0.3625, subjectivity=0.65)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# Positive
# Sentiment(polarity=-0.4, subjectivity=0.7)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.25000000000000006, subjectivity=0.35)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("tags")
plt.ylabel("Polarity")
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
